# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('sotuvlar.csv')

# %%
s_dt = data.sort_values(by="Date")

# %%
s_dt
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 496  556-97-7101      C  Naypyitaw        Normal  Female
# 484  493-65-6248      C  Naypyitaw        Member  Female
# 567  651-88-7328      A     Yangon        Normal  Female
# 523  133-14-7229      C  Naypyitaw        Normal    Male
# 970  746-04-1077      B   Mandalay        Member  Female
# ..           ...    ...        ...           ...     ...
# 393  308-47-4913      A     Yangon        Member  Female
# 73   841-35-6630      C  Naypyitaw        Normal  Female
# 433  616-87-0016      B   Mandalay        Normal    Male
# 585  127-47-6963      A     Yangon        Normal    Male
# 84   360-39-5055      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 496  Electronic accessories       63.22         2   6.3220  132.7620
# 484       Sports and travel       36.98        10  18.4900  388.2900
# 567     Fashion accessories       65.74         9  29.5830  621.2430
# ...

# %%
data_a = data.query('Branch == "A" ')
data_a
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
# ...

# %%
data_b = data.query('Branch == "B" ')
data_b
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 9    692-92-5582      B  Mandalay        Member  Female
# 10   351-62-0822      B  Mandalay        Member  Female
# 11   529-56-3974      B  Mandalay        Member    Male
# 15   299-46-1805      B  Mandalay        Member  Female
# 19   319-50-3348      B  Mandalay        Normal  Female
# ..           ...    ...       ...           ...     ...
# 987  552-44-5977      B  Mandalay        Member    Male
# 989  430-53-4718      B  Mandalay        Member    Male
# 991  602-16-6955      B  Mandalay        Normal  Female
# 993  690-01-6631      B  Mandalay        Normal    Male
# 996  303-96-2227      B  Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity  Tax 5%     Total  \
# 9        Food and beverages       54.84         3   8.226   172.746
# 10      Fashion accessories       14.48         4   2.896    60.816
# 11   Electronic accessories       25.51         4   5.102   107.142
# ...

# %%
data_c = data.query('Branch == "C" ')
data_c
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 20   300-71-4605      C  Naypyitaw        Member    Male
# 34   183-56-6882      C  Naypyitaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 983  148-41-7930      C  Naypyitaw        Normal    Male
# 984  189-40-5216      C  Naypyitaw        Normal    Male
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 5    Electronic accessories       85.39         7  29.8865  627.6165
# 7        Home and lifestyle       73.56        10  36.7800  772.3800
# ...

# %%
data_a.sort_values(by="Time").max()
# Out:
# Invoice ID                       898-04-2717
# Branch                                     A
# City                                  Yangon
# Customer type                         Normal
# Gender                                  Male
# Product line               Sports and travel
# Unit price                             99.83
# Quantity                                  10
# Tax 5%                                 49.49
# Total                                1039.29
# Date                                3/9/2019
# Time                                   20:59
# Payment                              Ewallet
# cogs                                   989.8
# gross margin percentage             4.761905
# gross income                           49.49
# Rating                                  10.0
# dtype: object

# %%
data_a.loc[(data_a.Time>'13:00')& (data_a.Time<'13:09')]
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 329  340-66-0321      A  Yangon        Member    Male  Electronic accessories
# 482  674-15-9296      A  Yangon        Normal    Male       Sports and travel
# 565  698-98-5964      A  Yangon        Normal  Female      Food and beverages
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0         74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 329       36.36         4   7.2720  152.7120  3/25/2019  13:07         Cash
# 482       37.14         5   9.2850  194.9850   1/8/2019  13:05      Ewallet
# 565       81.21        10  40.6050  852.7050  1/17/2019  13:01  Credit card
#
#        cogs  gross margin percentage  gross income  Rating
# 0    522.83                 4.761905       26.1415     9.1
# 329  145.44                 4.761905        7.2720     7.6
# ...

# %%
all_quant_a = data_a['Quantity'].sum()
all_quant_a
# Out:
# 1859

# %%
all_quant_b = data_b['Quantity'].sum()
all_quant_b
# Out:
# 1820

# %%
all_quant_c = data_c['Quantity'].sum()
all_quant_c
# Out:
# 1831

# %% [markdown]
# Branch A erkaklar soni:

# %%
br_a_male_c = len(data_a.query('Gender == "Male"'))
br_a_male_c
# Out:
# 179

# %% [markdown]
# Branch A ayollar soni:

# %%
br_a_female_c = len(data_a.query('Gender == "Female"'))
br_a_female_c
# Out:
# 161

# %% [raw]
# Branch B erkaklar soni:

# %%
br_b_male_c = len(data_b.query('Gender == "Male"'))
br_b_male_c
# Out:
# 170

# %% [markdown]
# Branch B ayollar soni:

# %%
br_b_female_c = len(data_b.query('Gender == "Female"'))
br_b_female_c
# Out:
# 162

# %% [markdown]
# Branch C erkaklar soni:

# %%
br_c_male_c = len(data_c.query('Gender == "Male"'))
br_c_male_c
# Out:
# 150

# %% [markdown]
# Branch C ayollar soni:

# %%
br_c_female_c = len(data_c.query('Gender == "Female"'))
br_c_female_c
# Out:
# 178

# %%
br_a_el_c = len(data_c.loc[data_c['Product line'] == 'Health and beauty'])
#br_a_el_c = data_a.loc[data_a['Product line'] == 'Electronic accessories']

br_a_el_c
# Out:
# 52

# %%
s_dt
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 496  556-97-7101      C  Naypyitaw        Normal  Female
# 484  493-65-6248      C  Naypyitaw        Member  Female
# 567  651-88-7328      A     Yangon        Normal  Female
# 523  133-14-7229      C  Naypyitaw        Normal    Male
# 970  746-04-1077      B   Mandalay        Member  Female
# ..           ...    ...        ...           ...     ...
# 393  308-47-4913      A     Yangon        Member  Female
# 73   841-35-6630      C  Naypyitaw        Normal  Female
# 433  616-87-0016      B   Mandalay        Normal    Male
# 585  127-47-6963      A     Yangon        Normal    Male
# 84   360-39-5055      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 496  Electronic accessories       63.22         2   6.3220  132.7620
# 484       Sports and travel       36.98        10  18.4900  388.2900
# 567     Fashion accessories       65.74         9  29.5830  621.2430
# ...

# %%
january_data = s_dt.loc[(s_dt['Date'] > '1/1/2019') & (s_dt['Date'] <= '1/31/2019')]#Yanvar oyiga sotuvlar datasi obshiy
jan_data_a = january_data.query('Branch == "A" ')#Yanvar oyiga sotuvlar datasi Branch "A" bo'yicha
jan_data_b = january_data.query('Branch == "B" ')#Yanvar oyiga sotuvlar datasi Branch "B" bo'yicha
jan_data_c = january_data.query('Branch == "C" ')#Yanvar oyiga sotuvlar datasi Branch "C" bo'yicha

# %%
february_data = s_dt.loc[(s_dt['Date'] > '2/1/2019') & (s_dt['Date'] <= '2/29/2019')]#Fevral oyiga sotuvlar datasi obshiy
feb_data_a = february_data.query('Branch == "A" ')#Fevral oyiga sotuvlar datasi Branch "A" bo'yicha
feb_data_b = february_data.query('Branch == "B" ')#Fevral oyiga sotuvlar datasi Branch "B" bo'yicha
feb_data_c = february_data.query('Branch == "C" ')#Fevral oyiga sotuvlar datasi Branch "C" bo'yicha

# %%
march_data = s_dt.loc[(s_dt['Date'] > '3/1/2019') & (s_dt['Date'] <= '3/31/2019')]#Mart oyiga sotuvlar datasi obshiy
mar_data_a = march_data.query('Branch == "A" ')#Mart oyiga sotuvlar datasi Branch "A" bo'yicha
mar_data_b = march_data.query('Branch == "B" ')#Mart oyiga sotuvlar datasi Branch "B" bo'yicha
mar_data_c = march_data.query('Branch == "C" ')#Mart oyiga sotuvlar datasi Branch "C" bo'yicha

# %%
jan_br_a_male_c = len(jan_data_a.query('Gender == "Male"'))#Yanvar oyiga Branch "A" erkaklar soni
jan_br_a_female_c = len(jan_data_a.query('Gender == "Female"'))#Yanvar oyiga Branch "A" ayollar soni
#--------------------------------------
feb_br_a_male_c = len(feb_data_a.query('Gender == "Male"'))#Fevral oyiga Branch "A" erkaklar soni
feb_br_a_female_c = len(feb_data_a.query('Gender == "Female"'))#Fevral oyiga Branch "A" ayollar soni
#--------------------------------------
mar_br_a_male_c = len(mar_data_a.query('Gender == "Male"'))#Mart oyiga Branch "A" erkaklar soni
mar_br_a_female_c = len(mar_data_a.query('Gender == "Female"'))#Mart oyiga Branch "A" ayollar soni

#----------------------------------------------------------------

jan_br_b_male_c = len(jan_data_b.query('Gender == "Male"'))#Yanvar oyiga Branch "B" erkaklar soni
jan_br_b_female_c = len(jan_data_b.query('Gender == "Female"'))#Yanvar oyiga Branch "B" ayollar soni
#--------------------------------------
feb_br_b_male_c = len(feb_data_b.query('Gender == "Male"'))#Fevral oyiga Branch "B" erkaklar soni
feb_br_b_female_c = len(feb_data_b.query('Gender == "Female"'))#Fevral oyiga Branch "B" ayollar soni
#--------------------------------------
mar_br_b_male_c = len(mar_data_b.query('Gender == "Male"'))#Mart oyiga Branch "B" erkaklar soni
mar_br_b_female_c = len(mar_data_b.query('Gender == "Female"'))#Mart oyiga Branch "B" ayollar soni

#----------------------------------------------------------------

jan_br_c_male_c = len(jan_data_c.query('Gender == "Male"'))#Yanvar oyiga Branch "C" erkaklar soni
jan_br_c_female_c = len(jan_data_c.query('Gender == "Female"'))#Yanvar oyiga Branch "C" ayollar soni
#--------------------------------------
feb_br_c_male_c = len(feb_data_c.query('Gender == "Male"'))#Fevral oyiga Branch "C" erkaklar soni
feb_br_c_female_c = len(feb_data_c.query('Gender == "Female"'))#Fevral oyiga Branch "C" ayollar soni
#--------------------------------------
mar_br_c_male_c = len(mar_data_c.query('Gender == "Male"'))#Mart oyiga Branch "C" erkaklar soni
mar_br_c_female_c = len(mar_data_c.query('Gender == "Female"'))#Mart oyiga Branch "C" ayollar soni

# %%
jan_br_c_female_c
# Out:
# 49

# %% [markdown]
# Branch "A" hamma tovarlar sotilgan royhati oylar bo'yicha

# %%
jan_health_and_beauty_br_a = len(jan_data_a.loc[jan_data_a['Product line'] == 'Health and beauty']) 
jan_electronic_accessories_br_a = len(jan_data_a.loc[jan_data_a['Product line'] == 'Electronic accessories'])
jan_home_and_lifestyle_br_a = len(jan_data_a.loc[jan_data_a['Product line'] == 'Home and lifestyle'])
jan_sports_and_travel_br_a = len(jan_data_a.loc[jan_data_a['Product line'] == 'Sports and travel'])
jan_food_and_beverages_br_a = len(jan_data_a.loc[jan_data_a['Product line'] == 'Food and beverages'])
#-----------------------------
feb_health_and_beauty_br_a = len(feb_data_a.loc[feb_data_a['Product line'] == 'Health and beauty']) 
feb_electronic_accessories_br_a = len(feb_data_a.loc[feb_data_a['Product line'] == 'Electronic accessories'])
feb_home_and_lifestyle_br_a = len(feb_data_a.loc[feb_data_a['Product line'] == 'Home and lifestyle'])
feb_sports_and_travel_br_a = len(feb_data_a.loc[feb_data_a['Product line'] == 'Sports and travel'])
feb_food_and_beverages_br_a = len(feb_data_a.loc[feb_data_a['Product line'] == 'Food and beverages'])
#-----------------------------
mar_health_and_beauty_br_a = len(mar_data_a.loc[mar_data_a['Product line'] == 'Health and beauty']) 
mar_electronic_accessories_br_a = len(mar_data_a.loc[mar_data_a['Product line'] == 'Electronic accessories'])
mar_home_and_lifestyle_br_a = len(mar_data_a.loc[mar_data_a['Product line'] == 'Home and lifestyle'])
mar_sports_and_travel_br_a = len(mar_data_a.loc[mar_data_a['Product line'] == 'Sports and travel'])
mar_food_and_beverages_br_a = len(mar_data_a.loc[mar_data_a['Product line'] == 'Food and beverages'])

mar_health_and_beauty_br_a
# Out:
# 15

# %% [markdown]
# Branch "B" hamma tovarlar sotilgan royhati oylar bo'yicha

# %%
jan_health_and_beauty_br_b = len(jan_data_b.loc[jan_data_b['Product line'] == 'Health and beauty']) 
jan_electronic_accessories_br_b = len(jan_data_b.loc[jan_data_b['Product line'] == 'Electronic accessories'])
jan_home_and_lifestyle_br_b = len(jan_data_b.loc[jan_data_b['Product line'] == 'Home and lifestyle'])
jan_sports_and_travel_br_b = len(jan_data_b.loc[jan_data_b['Product line'] == 'Sports and travel'])
jan_food_and_beverages_br_b = len(jan_data_b.loc[jan_data_b['Product line'] == 'Food and beverages'])
#-----------------------------
feb_health_and_beauty_br_b = len(feb_data_b.loc[feb_data_b['Product line'] == 'Health and beauty']) 
feb_electronic_accessories_br_b = len(feb_data_b.loc[feb_data_b['Product line'] == 'Electronic accessories'])
feb_home_and_lifestyle_br_b = len(feb_data_b.loc[feb_data_b['Product line'] == 'Home and lifestyle'])
feb_sports_and_travel_br_b = len(feb_data_b.loc[feb_data_b['Product line'] == 'Sports and travel'])
feb_food_and_beverages_br_b = len(feb_data_b.loc[feb_data_b['Product line'] == 'Food and beverages'])
#-----------------------------
mar_health_and_beauty_br_b = len(mar_data_b.loc[mar_data_b['Product line'] == 'Health and beauty']) 
mar_electronic_accessories_br_b = len(mar_data_b.loc[mar_data_b['Product line'] == 'Electronic accessories'])
mar_home_and_lifestyle_br_b = len(mar_data_b.loc[mar_data_b['Product line'] == 'Home and lifestyle'])
mar_sports_and_travel_br_b = len(mar_data_b.loc[mar_data_b['Product line'] == 'Sports and travel'])
mar_food_and_beverages_br_b = len(mar_data_b.loc[mar_data_b['Product line'] == 'Food and beverages'])

# %% [markdown]
# Branch "C" hamma tovarlar sotilgan royhati oylar bo'yicha

# %%
jan_health_and_beauty_br_c = len(jan_data_c.loc[jan_data_c['Product line'] == 'Health and beauty']) 
jan_electronic_accessories_br_c = len(jan_data_c.loc[jan_data_c['Product line'] == 'Electronic accessories'])
jan_home_and_lifestyle_br_c = len(jan_data_c.loc[jan_data_c['Product line'] == 'Home and lifestyle'])
jan_sports_and_travel_br_c = len(jan_data_c.loc[jan_data_c['Product line'] == 'Sports and travel'])
jan_food_and_beverages_br_c = len(jan_data_c.loc[jan_data_c['Product line'] == 'Food and beverages'])
#-----------------------------
feb_health_and_beauty_br_c = len(feb_data_c.loc[feb_data_c['Product line'] == 'Health and beauty']) 
feb_electronic_accessories_br_c = len(feb_data_c.loc[feb_data_c['Product line'] == 'Electronic accessories'])
feb_home_and_lifestyle_br_c = len(feb_data_c.loc[feb_data_c['Product line'] == 'Home and lifestyle'])
feb_sports_and_travel_br_c = len(feb_data_c.loc[feb_data_c['Product line'] == 'Sports and travel'])
feb_food_and_beverages_br_c = len(feb_data_c.loc[feb_data_c['Product line'] == 'Food and beverages'])
#-----------------------------
mar_health_and_beauty_br_c = len(mar_data_c.loc[mar_data_c['Product line'] == 'Health and beauty']) 
mar_electronic_accessories_br_c = len(mar_data_c.loc[mar_data_c['Product line'] == 'Electronic accessories'])
mar_home_and_lifestyle_br_c = len(mar_data_c.loc[mar_data_c['Product line'] == 'Home and lifestyle'])
mar_sports_and_travel_br_c = len(mar_data_c.loc[mar_data_c['Product line'] == 'Sports and travel'])
mar_food_and_beverages_br_c = len(mar_data_c.loc[mar_data_c['Product line'] == 'Food and beverages'])

# %%
jan_health_and_beauty_br_b
# Out:
# 15

# %%
names = ['Health and beauty', 'Electronic accessories', 'Home and lifestyle', 'Sports and travel', 'Food and beverages']
values = [jan_health_and_beauty_br_a, jan_electronic_accessories_br_a, jan_home_and_lifestyle_br_a, jan_sports_and_travel_br_a, jan_food_and_beverages_br_a]

values_1 = [jan_health_and_beauty_br_b, jan_electronic_accessories_br_b, jan_home_and_lifestyle_br_b, jan_sports_and_travel_br_b, jan_food_and_beverages_br_b]

values_2 = [jan_health_and_beauty_br_c, jan_electronic_accessories_br_c, jan_home_and_lifestyle_br_c, jan_sports_and_travel_br_c, jan_food_and_beverages_br_c]
plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.title('January Branch A')
plt.xticks(rotation=90)

plt.subplot(132)
plt.bar(names, values_1)
plt.title('January Branch B')
plt.xticks(rotation=90)

plt.subplot(133)
plt.bar(names, values_2)
plt.title('January Branch C')
plt.xticks(rotation=90)


plt.show()
print(f'Male Branch A: {jan_br_a_male_c}')
print(f'Female Branch A: {jan_br_a_female_c}\n')
print(f'Male Branch B: {jan_br_b_male_c}')
print(f'Female Branch B: {jan_br_b_female_c}\n')
print(f'Male Branch C: {jan_br_c_male_c}')
print(f'Female Branch C: {jan_br_c_female_c}')
print(f'Overall: {jan_br_a_male_c+jan_br_a_female_c+jan_br_b_male_c+jan_br_b_female_c+jan_br_c_male_c+jan_br_c_female_c}')
# Out:
# Male Branch A: 56
# Female Branch A: 38
#
# Male Branch B: 46
# Female Branch B: 43
#
# Male Branch C: 46
# Female Branch C: 49
# Overall: 278

# %% [raw]
# Bu yerda Yanvar oyi boyicha batafsil Brenchlar bo'yicha batafsil malumotni ko'rishimiz mumkin
# Yanvar oyida Erkaklar soni ayyollarnikiga nisbatan sag'al ustunroq Branch C dan tashqari
# Men o'ylaymanki shundan kelib chiqib ko'rishimiz mumkin sports and travel turkumidagi tovarlar hamma Brenchlarda sotuv statistikasi yoquri...

# %%
names = ['Health and beauty', 'Electronic accessories', 'Home and lifestyle', 'Sports and travel', 'Food and beverages']
values = [feb_health_and_beauty_br_a, feb_electronic_accessories_br_a, feb_home_and_lifestyle_br_a, feb_sports_and_travel_br_a, feb_food_and_beverages_br_a]

values_1 = [feb_health_and_beauty_br_b, feb_electronic_accessories_br_b, feb_home_and_lifestyle_br_b, feb_sports_and_travel_br_b, feb_food_and_beverages_br_b]

values_2 = [feb_health_and_beauty_br_c, feb_electronic_accessories_br_c, feb_home_and_lifestyle_br_c, feb_sports_and_travel_br_c, feb_food_and_beverages_br_c]
plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.title('February Branch A')
plt.xticks(rotation=90)

plt.subplot(132)
plt.bar(names, values_1)
plt.title('February Branch B')
plt.xticks(rotation=90)

plt.subplot(133)
plt.bar(names, values_2)
plt.title('February Branch C')
plt.xticks(rotation=90)


plt.show()
print(f'Male Branch A: {feb_br_a_male_c}')
print(f'Female Branch A: {feb_br_a_female_c}\n')
print(f'Male Branch B: {feb_br_b_male_c}')
print(f'Female Branch B: {feb_br_b_female_c}\n')
print(f'Male Branch C: {feb_br_c_male_c}')
print(f'Female Branch C: {feb_br_c_female_c}')
print(f'Overall: {feb_br_a_male_c+feb_br_a_female_c+feb_br_b_male_c+feb_br_b_female_c+feb_br_c_male_c+feb_br_c_female_c}')
# Out:
# Male Branch A: 30
# Female Branch A: 33
#
# Male Branch B: 38
# Female Branch B: 38
#
# Male Branch C: 24
# Female Branch C: 39
# Overall: 202

# %% [markdown]
# Fevral oyida bo'lsa odamlarning soni keskin tushib ketgan, xar bir biznesda ozini mertviy sezon digan payiti bo'ladi, bu degani hech qanday asossiz sovdani keskin tushib ketishini aytiladi
# nega fevral oyini mertviy sezon deb aytyapman?, chunki yuqorida ko'rganimizdak yanvar oyi sovda normal darajada bo'lgan va bundan keyingi mart oyidaham so'vdalar o'z o'rniga chiqmoqda!

# %%
names = ['Health and beauty', 'Electronic accessories', 'Home and lifestyle', 'Sports and travel', 'Food and beverages']
values = [mar_health_and_beauty_br_a, mar_electronic_accessories_br_a, mar_home_and_lifestyle_br_a, mar_sports_and_travel_br_a, mar_food_and_beverages_br_a]

values_1 = [mar_health_and_beauty_br_b, mar_electronic_accessories_br_b, mar_home_and_lifestyle_br_b, mar_sports_and_travel_br_b, mar_food_and_beverages_br_b]

values_2 = [mar_health_and_beauty_br_c, mar_electronic_accessories_br_c, mar_home_and_lifestyle_br_c, mar_sports_and_travel_br_c, mar_food_and_beverages_br_c]
plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.title('March Branch A')
plt.xticks(rotation=90)

plt.subplot(132)
plt.bar(names, values_1)
plt.title('March Branch B')
plt.xticks(rotation=90)

plt.subplot(133)
plt.bar(names, values_2)
plt.title('March Branch C')
plt.xticks(rotation=90)


plt.show()
print(f'Male Branch A: {mar_br_a_male_c}')
print(f'Female Branch A: {mar_br_a_female_c}\n')
print(f'Male Branch B: {mar_br_b_male_c}')
print(f'Female Branch B: {mar_br_b_female_c}\n')
print(f'Male Branch C: {mar_br_c_male_c}')
print(f'Female Branch C: {mar_br_c_female_c}')
print(f'Overall: {mar_br_a_male_c+mar_br_a_female_c+mar_br_b_male_c+mar_br_b_female_c+mar_br_c_male_c+mar_br_c_female_c}')
# Out:
# Male Branch A: 51
# Female Branch A: 45
#
# Male Branch B: 42
# Female Branch B: 39
#
# Male Branch C: 46
# Female Branch C: 36
# Overall: 259

# %% [markdown]
# Mana Mart oyigaham yetib keldik, ko'rib turganimizdak mart oyida mertviy sezodan chiqdi, va yana stabil sovda davom etmoqda

# %% [markdown]
# Men shu magazinlarning egasiga tavsiya qilardimki, Elektronika aksessuarlarni bemalol zapasi bilan olib qo'yishi mumkin, Chunki o'lik sezondaham elektronika aksessuarlari yahshi sotilgan,
# va sotilmay qolib ketmasligiga 85% kafolat berolaman
